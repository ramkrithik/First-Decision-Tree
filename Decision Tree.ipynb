# %% [markdown]
# <a href="https://colab.research.google.com/github/ramkrithik/First-Decision-Tree/blob/master/Decision%20Tree.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np

from sklearn.tree import DecisionTreeClassifier
from sklearn.tree import export_graphviz
from sklearn.externals.six import StringIO  

from IPython.display import Image  
import pydotplus

# %%
df=pd.read_csv("/content/data/skyserver.csv")
df.head()
# Out:
#           objid          ra       dec  ...  plate    mjd  fiberid
# 0  1.237650e+18  183.531326  0.089693  ...   3306  54922      491
# 1  1.237650e+18  183.598371  0.135285  ...    323  51615      541
# 2  1.237650e+18  183.680207  0.126185  ...    287  52023      513
# 3  1.237650e+18  183.870529  0.049911  ...   3306  54922      510
# 4  1.237650e+18  183.883288  0.102557  ...   3306  54922      512
#
# [5 rows x 18 columns]

# %%
df.shape
# Out:
# (10000, 18)

# %%
df['class'].unique()
# Out:
# array(['STAR', 'GALAXY', 'QSO'], dtype=object)

# %%
classes={
    'STAR':0,'GALAXY':1,'QSO':2
}
df=df.replace({'class':classes})

# %%
df.head()
# Out:
#           objid          ra       dec  ...  plate    mjd  fiberid
# 0  1.237650e+18  183.531326  0.089693  ...   3306  54922      491
# 1  1.237650e+18  183.598371  0.135285  ...    323  51615      541
# 2  1.237650e+18  183.680207  0.126185  ...    287  52023      513
# 3  1.237650e+18  183.870529  0.049911  ...   3306  54922      510
# 4  1.237650e+18  183.883288  0.102557  ...   3306  54922      512
#
# [5 rows x 18 columns]

# %%
for i in range(df.shape[1]):
    column=df.iloc[:,i]
    print(df.iloc[:,i].values)
    for j in column:
        if(j>100000):
            df.drop(df.columns[i],axis=1,inplace=True)
            i+=1
            break
# Out:
# [1.23765e+18 1.23765e+18 1.23765e+18 ... 1.23765e+18 1.23765e+18
#  1.23765e+18]
# [ 0.08969303  0.13528503  0.12618509 ... 51.66698638 51.75306779
#  51.80530747]
# [19.47406 18.6628  19.38298 ... 18.75818 18.88287 19.27586]
# [17.0424  17.21449 18.19169 ... 17.77784 17.91068 17.37829]
# [15.94699 16.67637 17.47428 ... 17.51872 17.53152 16.30542]
# [15.50342 16.48922 17.08732 ... 17.43302 17.36284 15.83548]
# [15.22531 16.3915  16.80125 ... 17.42048 17.13988 15.50588]
# [ 752  752  752 ... 1345 1345 1345]
# [301 301 301 ... 301 301 301]
# [4 4 4 ... 3 3 3]
# [267 267 268 ... 162 163 163]
# [3.72236e+18 3.63814e+17 3.23274e+17 ... 8.22262e+18 5.03340e+17
#  5.03341e+17]
# [-8.960000e-06 -5.490000e-05  1.231112e-01 ... -4.015730e-04  1.401894e-02
#   1.184173e-01]
# [3306  323  287 ... 7303  447  447]
# [54922 51615 52023 ... 57013 51877 51877]
# [491 541 513 ... 622 229 233]
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-9-95da3db9072e> in <module>()
#       1 for i in range(df.shape[1]):
# ----> 2     column=df.iloc[:,i]
#       3     print(df.iloc[:,i].values)
#       4     for j in column:
#       5         if(j>100000):
#
# /usr/local/lib/python3.6/dist-packages/pandas/core/indexing.py in __getitem__(self, key)
#    1760                 except (KeyError, IndexError, AttributeError):
#    1761                     pass
# -> 1762             return self._getitem_tuple(key)
#    1763         else:
#    1764             # we by definition only have the 0th axis
#
# /usr/local/lib/python3.6/dist-packages/pandas/core/indexing.py in _getitem_tuple(self, tup)
#    2065     def _getitem_tuple(self, tup: Tuple):
#    2066
# -> 2067         self._has_valid_tuple(tup)
#    2068         try:
#    2069             return self._getitem_lowerdim(tup)
#
# /usr/local/lib/python3.6/dist-packages/pandas/core/indexing.py in _has_valid_tuple(self, key)
#     701                 raise IndexingError("Too many indexers")
#     702             try:
# --> 703                 self._validate_key(k, i)
#     704             except ValueError:
#     705                 raise ValueError(
#
# /usr/local/lib/python3.6/dist-packages/pandas/core/indexing.py in _validate_key(self, key, axis)
#    1992             return
#    1993         elif is_integer(key):
# -> 1994             self._validate_integer(key, axis)
#    1995         elif isinstance(key, tuple):
#    1996             # a tuple should already have been caught by this point
#
# /usr/local/lib/python3.6/dist-packages/pandas/core/indexing.py in _validate_integer(self, key, axis)
#    2061         len_axis = len(self.obj._get_axis(axis))
#    2062         if key >= len_axis or key < -len_axis:
# -> 2063             raise IndexError("single positional indexer is out-of-bounds")
#    2064
#    2065     def _getitem_tuple(self, tup: Tuple):
#
# IndexError: single positional indexer is out-of-bounds

# %%
df.head()
# Out:
#            ra       dec         u         g  ...  redshift  plate    mjd  fiberid
# 0  183.531326  0.089693  19.47406  17.04240  ... -0.000009   3306  54922      491
# 1  183.598371  0.135285  18.66280  17.21449  ... -0.000055    323  51615      541
# 2  183.680207  0.126185  19.38298  18.19169  ...  0.123111    287  52023      513
# 3  183.870529  0.049911  17.76536  16.60272  ... -0.000111   3306  54922      510
# 4  183.883288  0.102557  17.55025  16.26342  ...  0.000590   3306  54922      512
#
# [5 rows x 16 columns]

# %%
df.shape
# Out:
# (10000, 16)

# %%
ins=df['class'].value_counts()
print(ins)
# Out:
# 1    4998
# 0    4152
# 2     850
# Name: class, dtype: int64

# %%
column_names=["ra","dec","u","g","r","i","z","run","rerun","camcol","field","redshift","plate","mjd","fiberid","class"]
df = df.reindex(columns=column_names)
df.head()
# Out:
#            ra       dec         u         g  ...  plate    mjd  fiberid  class
# 0  183.531326  0.089693  19.47406  17.04240  ...   3306  54922      491      0
# 1  183.598371  0.135285  18.66280  17.21449  ...    323  51615      541      0
# 2  183.680207  0.126185  19.38298  18.19169  ...    287  52023      513      1
# 3  183.870529  0.049911  17.76536  16.60272  ...   3306  54922      510      0
# 4  183.883288  0.102557  17.55025  16.26342  ...   3306  54922      512      0
#
# [5 rows x 16 columns]

# %%
x=np.array(df.iloc[:,:15])
y=np.array(df.iloc[:,15])
print(x.shape)
print(y.shape)
# Out:
# (10000, 15)
# (10000,)

# %%
tree = DecisionTreeClassifier(criterion='entropy',max_depth=10)
tree.fit(x,y)
# Out:
# DecisionTreeClassifier(ccp_alpha=0.0, class_weight=None, criterion='entropy',
#                        max_depth=10, max_features=None, max_leaf_nodes=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, presort='deprecated',
#                        random_state=None, splitter='best')

# %%
dot_data = StringIO()
export_graphviz(tree, out_file=dot_data,  
                filled=True, rounded=True,
                special_characters=True)
graph = pydotplus.graph_from_dot_data(dot_data.getvalue())  
Image(graph.create_png(), width=1000, height=1000)

# %%
predict = tree.predict(x)
predict
# Out:
# array([0, 0, 1, ..., 0, 1, 1])

# %%
from sklearn import metrics
print('Accucary:', metrics.accuracy_score(y, predict))
# Out:
# Accucary: 0.9984
